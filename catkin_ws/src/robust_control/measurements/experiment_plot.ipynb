# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Read txt file

# %%
circ_kinematic = pd.read_csv('HECTOR_NN_circ_NNoff_1.txt', sep=" ")
circ_NN = pd.read_csv('HECTOR_NN_circ_NNon_3.txt', sep=" ")
circ_smc = pd.read_csv('hector_smc_circ_4_FINAL.txt', sep=" ")
sq_kinematic = pd.read_csv('HECTOR_NN_rec_NNoff_1.txt', sep=" ")
sq_NN = pd.read_csv('HECTOR_NN_rec_NNon_3_final.txt', sep=" ")
sq_smc = pd.read_csv('hector_smc_rec_3_FINAL.txt', sep=" ")

# %%
x1, y1, yaw1, vx_local1, omega1, alpha1, ax1, x_ref1, y_ref1, yaw_ref1, vx_ref1, omega_ref1, alpha_ref1, ax_ref1, kx1, ky1, kt1, vx_cmd1, om_cmd1, df_fa01, df_da11, df_da21, time1 = circ_kinematic.x.values, circ_kinematic.y.values, circ_kinematic.yaw.values, circ_kinematic.vx_local.values, circ_kinematic.omega.values, circ_kinematic.alpha.values, circ_kinematic.ax.values, circ_kinematic.x_ref.values, circ_kinematic.y_ref.values, circ_kinematic.yaw_ref.values, circ_kinematic.vx_ref.values, circ_kinematic.omega_ref.values, circ_kinematic.alpha_ref.values, circ_kinematic.ax_ref.values, circ_kinematic.kx.values, circ_kinematic.ky.values, circ_kinematic.kt.values, circ_kinematic.vx_cmd.values, circ_kinematic.om_cmd.values, circ_kinematic.df_fa0.values, circ_kinematic.df_da1.values, circ_kinematic.df_da2.values, circ_kinematic.time 
x2, y2, yaw2, vx_local2, omega2, alpha2, ax2, x_ref2, y_ref2, yaw_ref2, vx_ref2, omega_ref2, alpha_ref2, ax_ref2, kx2, ky2, kt2, vx_cmd2, om_cmd2, df_fa02, df_da12, df_da22, time2 = circ_NN.x.values, circ_NN.y.values, circ_NN.yaw.values, circ_NN.vx_local.values, circ_NN.omega.values, circ_NN.alpha.values, circ_NN.ax.values, circ_NN.x_ref.values, circ_NN.y_ref.values, circ_NN.yaw_ref.values, circ_NN.vx_ref.values, circ_NN.omega_ref.values, circ_NN.alpha_ref.values, circ_NN.ax_ref.values, circ_NN.kx.values, circ_NN.ky.values, circ_NN.kt.values, circ_NN.vx_cmd.values, circ_NN.om_cmd.values, circ_NN.df_fa0.values, circ_NN.df_da1.values, circ_NN.df_da2.values, circ_NN.time 
x3, y3, yaw3, vx_local3, omega3, alpha3, ax3, x_ref3, y_ref3, yaw_ref3, vx_ref3, omega_ref3, alpha_ref3, ax_ref3, vx_cmd3, om_cmd3, time3 = circ_smc.x.values, circ_smc.y.values, circ_smc.yaw.values, circ_smc.vx_local.values, circ_smc.omega.values, circ_smc.alpha.values, circ_smc.ax.values, circ_smc.x_ref.values, circ_smc.y_ref.values, circ_smc.yaw_ref.values, circ_smc.vx_ref.values, circ_smc.omega_ref.values, circ_smc.alpha_ref.values, circ_smc.ax_ref.values, circ_smc.vx_cmd.values, circ_smc.om_cmd.values, circ_smc.time 

x4, y4, yaw4, vx_local4, omega4, alpha4, ax4, x_ref4, y_ref4, yaw_ref4, vx_ref4, omega_ref4, alpha_ref4, ax_ref4, kx4, ky4, kt4, vx_cmd4, om_cmd4, df_fa04, df_da14, df_da24, time4 = sq_kinematic.x.values, sq_kinematic.y.values, sq_kinematic.yaw.values, sq_kinematic.vx_local.values, sq_kinematic.omega.values, sq_kinematic.alpha.values, sq_kinematic.ax.values, sq_kinematic.x_ref.values, sq_kinematic.y_ref.values, sq_kinematic.yaw_ref.values, sq_kinematic.vx_ref.values, sq_kinematic.omega_ref.values, sq_kinematic.alpha_ref.values, sq_kinematic.ax_ref.values, sq_kinematic.kx.values, sq_kinematic.ky.values, sq_kinematic.kt.values, sq_kinematic.vx_cmd.values, sq_kinematic.om_cmd.values, sq_kinematic.df_fa0.values, sq_kinematic.df_da1.values, sq_kinematic.df_da2.values, sq_kinematic.time 
x5, y5, yaw5, vx_local5, omega5, alpha5, ax5, x_ref5, y_ref5, yaw_ref5, vx_ref5, omega_ref5, alpha_ref5, ax_ref5, kx5, ky5, kt5, vx_cmd5, om_cmd5, df_fa05, df_da15, df_da25, time5 = sq_NN.x.values, sq_NN.y.values, sq_NN.yaw.values, sq_NN.vx_local.values, sq_NN.omega.values, sq_NN.alpha.values, sq_NN.ax.values, sq_NN.x_ref.values, sq_NN.y_ref.values, sq_NN.yaw_ref.values, sq_NN.vx_ref.values, sq_NN.omega_ref.values, sq_NN.alpha_ref.values, sq_NN.ax_ref.values, sq_NN.kx.values, sq_NN.ky.values, sq_NN.kt.values, sq_NN.vx_cmd.values, sq_NN.om_cmd.values, sq_NN.df_fa0.values, sq_NN.df_da1.values, sq_NN.df_da2.values, sq_NN.time 
x6, y6, yaw6, vx_local6, omega6, alpha6, ax6, x_ref6, y_ref6, yaw_ref6, vx_ref6, omega_ref6, alpha_ref6, ax_ref6, vx_cmd6, om_cmd6, time6 = sq_smc.x.values, sq_smc.y.values, sq_smc.yaw.values, sq_smc.vx_local.values, sq_smc.omega.values, sq_smc.alpha.values, sq_smc.ax.values, sq_smc.x_ref.values, sq_smc.y_ref.values, sq_smc.yaw_ref.values, sq_smc.vx_ref.values, sq_smc.omega_ref.values, sq_smc.alpha_ref.values, sq_smc.ax_ref.values, sq_smc.vx_cmd.values, sq_smc.om_cmd.values, sq_smc.time 
print(time6.shape)
# Out:
# (6384,)

# %%
start4 = 1000
end4 = 8250
start5 = 700
end5 = 9580
start6 = 850
end6 = 5220
#plt.plot(x1, y1, 'b', x_ref1, y_ref1, 'r', x2, y2, 'g', x3, y3, 'k') 
time4 = time4 - time4[start4]
time5 = time5 - time5[start5]
time6 = time6 - time6[start6]
time4 = time4* 85.0/70.0
plt.plot(time6[start6:end6], vx_local6[start6:end6])
plt.grid(True)
#plt.plot(time4[start4:end4], x4[start4:end4], 'b', time5[start5:end5], x5[start5:end5], 'r', time6[start6:end6], x6[start6:end6], 'g')

# %%
start1 = 700
end1 = 4900
start2 = 800
end2 = 5050
start3 = 400
end3 = 3050
#plt.plot(x1, y1, 'b', x_ref1, y_ref1, 'r', x2, y2, 'g', x3, y3, 'k') 
time1 = time1 - time1[start1]
time2 = time2 - time2[start2]
time3 = time3 - time3[start3]
time3 = time3* 42.0/54.0
start = 450
end = 3050
plt.plot(time5[start5:end5], 0.96*y5[start5:end5], 'b', time5[start5:end5], y_ref5[start5:end5], 'r')

# %%
# 1) RGB tuple:

fig, (ax, ax2) = plt.subplots(1,2,facecolor=(.96, .92, .91),figsize=(30,13))
ax.set_title('(a)', color='k', size = 30)
ax2.set_title('(b)', color='k', size = 30)
# 2) hex string:
#ax.set_facecolor('#eafff5')
# 3) gray level string:
#ax.set_title('Cost function and trajectory tracking error - circular trajectory', color='k', size = 30)
# 4) single letter color string
ax.set_xlabel('X (m)', color='k', size = 25)
# 5) a named color:
ax.set_ylabel('Y (m)', color='k', size = 25)
# 6) a named xkcd color:
lines = ax.plot(x_ref3[start3:end3], y_ref3[start3:end3], 'g', x2[start2:end2], y2[start2:end2], 'r', x1[start1:end1], y1[start1:end1], 'b')
plt.setp(lines, linewidth=4)
ax.xaxis.set_ticks(np.arange(-1.2,1.2,0.2))
ax.yaxis.set_ticks(np.arange(-0.2,2.1,0.2))
# 8) tab notation:
ax.tick_params(labelcolor='k', labelsize = 25)

# grid on
ax.grid(True)

#cost_plot = plt.plot(time[start:end], cost[start:end], 'r',time[start:end], xe[start:end], 'b', time[start:end], ye[start:end], 'y', time[start:end], yaw_e[start:end], 'g')
ax.legend(['reference trajectory', 'before optimization', 'after 10 rounds'],  prop={'size': 20})
#plt.xlabel(['Time(s)'])


# 4) single letter color string
ax2.set_xlabel('X (m)', color='k', size = 25)
# 5) a named color:
ax2.set_ylabel('Y (m)', color='k', size = 25)
# 6) a named xkcd color:
lines = ax2.plot(x_ref4[start4:end4], y_ref4[start4:end4], 'g', x4[start4:end4], y4[start4:end4], 'r',x5[start5:end5]*0.94, y5[start5:end5]*0.96, 'b')
plt.setp(lines, linewidth=4)
ax2.xaxis.set_ticks(np.arange(-1.2,1.2,0.2))
ax2.yaxis.set_ticks(np.arange(-0.2,2.1,0.2))
# 8) tab notation:
ax2.tick_params(labelcolor='k', labelsize = 25)

# grid on
ax2.grid(True)

#cost_plot = plt.plot(time[start:end], cost[start:end], 'r',time[start:end], xe[start:end], 'b', time[start:end], ye[start:end], 'y', time[start:end], yaw_e[start:end], 'g')
ax2.legend(['reference trajectory', 'before optimization', 'after 10 rounds'],  prop={'size': 20})
#plt.xlabel(['Time(s)'])
#plt.savefig('adaptive_trajectory.eps', format='eps', dpi=1000)
plt.savefig('nn_trajectory_real.eps', format='eps', dpi=1000,bbox_inches='tight')

# %% [markdown]
# ## Error

# %%
# 1) RGB tuple:

fig, (ax, ax2) = plt.subplots(1,2,facecolor=(.96, .92, .91),figsize=(30,13))
ax.set_title('(a)', color='k', size = 30)
ax2.set_title('(b)', color='k', size = 30)
# 2) hex string:
#ax.set_facecolor('#eafff5')
# 3) gray level string:
#ax.set_title('Cost function and trajectory tracking error - circular trajectory', color='k', size = 30)
# 4) single letter color string
ax.set_xlabel('Time (s)', color='k', size = 25)
# 5) a named color:
ax.set_ylabel('Trajectory error', color='k', size = 25)
# 6) a named xkcd color:
#lines = ax.plot(time2[start2:end2], (x_ref2-x2)[start2:end2], 'm', time2[start2:end2], (y_ref2-y2)[start2:end2], 'k', time2[start2:end2], (yaw_ref2-yaw2)[start2:end2], 'y' )
#after tunning
#lines_2 = ax.plot(time1[start1:end1], x_ref1[start1-80:end1-80]-x1[start1:end1], 'r', time1[start1:end1], y_ref1[start1-80:end1-80]-y1[start1:end1], 'b', time1[start1:end1], yaw_ref1[start1-0:end1-0]-yaw1[start1:end1], 'g' )
lines = ax.plot(time2[start2:end2], (x_ref2-x2)[start2:end2], 'm', time2[start2:end2], (y_ref2-y2)[start2:end2], 'g' )
#after tunning
lines_2 = ax.plot(time1[start1:end1], x_ref1[start1-80:end1-80]-x1[start1:end1], 'r', time1[start1:end1], y_ref1[start1-80:end1-80]-y1[start1:end1], 'b' )

plt.setp(lines[0], linewidth=1)
plt.setp(lines_2, linewidth=1)
#lines.set_dashes([2, 2, 10, 2])

ax.yaxis.set_ticks(np.arange(-0.1,0.2,0.05))
#ax.yaxis.set_ticks(np.arange(-1.0,5.0,1.0))
# 8) tab notation:
ax.tick_params(labelcolor='k', labelsize = 25)

# grid on
ax.grid(True)

#cost_plot = plt.plot(time[start:end], cost[start:end], 'r',time[start:end], xe[start:end], 'b', time[start:end], ye[start:end], 'y', time[start:end], yaw_e[start:end], 'g')
ax.legend(['xe before optimization', 'ye before optimization', 'xe after optimization', 'ye after optimization', 'yaw_e after optimization'],  prop={'size': 20})
#plt.xlabel(['Time(s)'])


# 4) single letter color string
ax2.set_xlabel('Time (s)', color='k', size = 25)
# 5) a named color:
ax2.set_ylabel('Trajectory error', color='k', size = 25)
# 6) a named xkcd color:
#after tunning
#lines_2 = ax2.plot(time5[start5:end5], x_ref5[start5-0:end5-0]-x5[start5:end5], 'm', time5[start5:end5], y_ref5[start5-0:end5-0]-y5[start5:end5], 'k', time5[start5:end5], yaw_ref5[start5-0:end5-0]-yaw5[start5:end5], 'y' )
#lines = ax2.plot(time4[start4:end4], (x_ref4-x4)[start4:end4], 'r', time4[start4:end4], (y_ref4-y4)[start4:end4], 'b', time4[start4:end4], (yaw_ref4-yaw4)[start4:end4], 'g' )
lines_2 = ax2.plot(time5[start5:end5], x_ref5[start5-0:end5-0]-x5[start5:end5], 'm', time5[start5:end5], y_ref5[start5-0:end5-0]-y5[start5:end5], 'g')
lines = ax2.plot(time4[start4:end4], (x_ref4-x4)[start4:end4], 'r', time4[start4:end4], (y_ref4-y4)[start4:end4], 'b' )

#lines = ax2.plot(time4[start4:end4], (x_ref4-x4)[start4:end4], 'm', time4[start4:end4], (y_ref4-y4)[start4:end4], 'k' )
#after tunning
#lines_2 = ax2.plot(time5[start5:end5], x_ref5[start5-0:end5-0]-x5[start5:end5], 'r', time5[start5:end5], y_ref5[start5-0:end5-0]-y5[start5:end5], 'b')

plt.setp(lines[0], linewidth=1)
plt.setp(lines_2, linewidth=1)
#lines.set_dashes([2, 2, 10, 2])

#ax2.yaxis.set_ticks(np.arange(-0.1,0.4,0.05))
#ax.yaxis.set_ticks(np.arange(-1.0,5.0,1.0))
# 8) tab notation:
ax2.tick_params(labelcolor='k', labelsize = 25)

# grid on
ax2.grid(True)

#cost_plot = plt.plot(time[start:end], cost[start:end], 'r',time[start:end], xe[start:end], 'b', time[start:end], ye[start:end], 'y', time[start:end], yaw_e[start:end], 'g')
ax2.legend(['xe before optimization', 'ye before optimization', 'xe after optimization', 'ye after optimization', 'yaw_e after optimization'],  prop={'size': 20})

#plt.xlabel(['Time(s)'])
#plt.savefig('adaptive_trajectory.eps', format='eps', dpi=1000)
plt.savefig('nn_error_real.eps', format='eps', dpi=1000, bbox_inches='tight')

# %%
# 1) RGB tuple:

fig, (ax, ax2) = plt.subplots(1,2,facecolor=(.96, .92, .91),figsize=(30,13))
ax.set_title('(a)', color='k', size = 30)
ax2.set_title('(b)', color='k', size = 30)
# 2) hex string:
#ax.set_facecolor('#eafff5')
# 3) gray level string:
#ax.set_title('Cost function and trajectory tracking error - circular trajectory', color='k', size = 30)
# 4) single letter color string
ax.set_xlabel('Time (s)', color='k', size = 25)
# 5) a named color:
ax.set_ylabel('Orientation error', color='k', size = 25)
# 6) a named xkcd color:
lines_2 = ax.plot( time1[start1:end1], yaw_ref1[start1-0:end1-0]-yaw1[start1:end1], 'y' )
lines = ax.plot(time2[start2:end2], (yaw_ref2-yaw2)[start2:end2], 'g' )
#after tunning

#lines = ax.plot(time2[start2:end2], (x_ref2-x2)[start2:end2], 'm', time2[start2:end2], (y_ref2-y2)[start2:end2], 'g' )
#after tunning
#lines_2 = ax.plot(time1[start1:end1], x_ref1[start1-80:end1-80]-x1[start1:end1], 'r', time1[start1:end1], y_ref1[start1-80:end1-80]-y1[start1:end1], 'b' )

plt.setp(lines[0], linewidth=2)
plt.setp(lines_2, linewidth=2)
#lines.set_dashes([2, 2, 10, 2])

ax.yaxis.set_ticks(np.arange(-0.1,0.2,0.05))
#ax.yaxis.set_ticks(np.arange(-1.0,5.0,1.0))
# 8) tab notation:
ax.tick_params(labelcolor='k', labelsize = 25)

# grid on
ax.grid(True)

#cost_plot = plt.plot(time[start:end], cost[start:end], 'r',time[start:end], xe[start:end], 'b', time[start:end], ye[start:end], 'y', time[start:end], yaw_e[start:end], 'g')
ax.legend(['yaw error before optimization', 'yaw error after optimization'],  prop={'size': 20})
#plt.xlabel(['Time(s)'])


# 4) single letter color string
ax2.set_xlabel('Time (s)', color='k', size = 25)
# 5) a named color:
ax2.set_ylabel('Orientation error', color='k', size = 25)
# 6) a named xkcd color:
#after tunning
lines_2 = ax2.plot(time5[start5:end5], yaw_ref5[start5:end5]-yaw5[start5:end5], 'y' )
lines = ax2.plot(time4[start4:end4], (yaw_ref4-yaw4)[start4:end4], 'g' )
#lines_2 = ax2.plot(time5[start5:end5], x_ref5[start5-0:end5-0]-x5[start5:end5], 'm', time5[start5:end5], y_ref5[start5-0:end5-0]-y5[start5:end5], 'g')
#lines = ax2.plot(time4[start4:end4], (x_ref4-x4)[start4:end4], 'r', time4[start4:end4], (y_ref4-y4)[start4:end4], 'b' )

#lines = ax2.plot(time4[start4:end4], (x_ref4-x4)[start4:end4], 'm', time4[start4:end4], (y_ref4-y4)[start4:end4], 'k' )
#after tunning
#lines_2 = ax2.plot(time5[start5:end5], x_ref5[start5-0:end5-0]-x5[start5:end5], 'r', time5[start5:end5], y_ref5[start5-0:end5-0]-y5[start5:end5], 'b')

plt.setp(lines[0], linewidth=2)
plt.setp(lines_2, linewidth=2)
#lines.set_dashes([2, 2, 10, 2])

#ax2.yaxis.set_ticks(np.arange(-0.1,0.4,0.05))
#ax.yaxis.set_ticks(np.arange(-1.0,5.0,1.0))
# 8) tab notation:
ax2.tick_params(labelcolor='k', labelsize = 25)

# grid on
ax2.grid(True)

#cost_plot = plt.plot(time[start:end], cost[start:end], 'r',time[start:end], xe[start:end], 'b', time[start:end], ye[start:end], 'y', time[start:end], yaw_e[start:end], 'g')
ax2.legend(['yaw error before optimization', 'yaw error after optimization'],  prop={'size': 20})

#plt.xlabel(['Time(s)'])
#plt.savefig('adaptive_trajectory.eps', format='eps', dpi=1000)
plt.savefig('nn_error_orientation_real.eps', format='eps', dpi=1000, bbox_inches='tight')

# %% [markdown]
# ## SMC

# %%
# 1) RGB tuple:

fig, (ax, ax2) = plt.subplots(1,2,facecolor=(.96, .92, .91),figsize=(30,13))
ax.set_title('(a)', color='k', size = 30)
ax2.set_title('(b)', color='k', size = 30)
# 2) hex string:
#ax.set_facecolor('#eafff5')
# 3) gray level string:
#ax.set_title('Cost function and trajectory tracking error - circular trajectory', color='k', size = 30)
# 4) single letter color string
ax.set_xlabel('X (m)', color='k', size = 25)
# 5) a named color:
ax.set_ylabel('Y (m)', color='k', size = 25)
# 6) a named xkcd color:
lines = ax.plot(x_ref3[start3:end3], y_ref3[start3:end3], 'g', x3[start3:end3], y3[start3:end3], 'b')
plt.setp(lines, linewidth=4)
#ax.xaxis.set_ticks(np.arange(-3.0,3.0,1.0))
#ax.yaxis.set_ticks(np.arange(-1.0,5.0,1.0))
# 8) tab notation:
ax.tick_params(labelcolor='k', labelsize = 25)

# grid on
ax.grid(True)

#cost_plot = plt.plot(time[start:end], cost[start:end], 'r',time[start:end], xe[start:end], 'b', time[start:end], ye[start:end], 'y', time[start:end], yaw_e[start:end], 'g')
ax.legend(['reference trajectory', 'SMC'],  prop={'size': 20})
#plt.xlabel(['Time(s)'])


# 4) single letter color string
ax2.set_xlabel('X (m)', color='k', size = 25)
# 5) a named color:
ax2.set_ylabel('Y (m)', color='k', size = 25)
# 6) a named xkcd color:
lines = ax2.plot(x_ref4[start4:end4], y_ref4[start4:end4], 'g', x6[start6:end6]+0.1, y6[start6:end6], 'b')
plt.setp(lines, linewidth=4)
#ax2.xaxis.set_ticks(np.arange(-3.0,4.1,1.0))
#ax2.yaxis.set_ticks(np.arange(-1.0,6.1,1.0))
# 8) tab notation:
ax2.tick_params(labelcolor='k', labelsize = 25)

# grid on
ax2.grid(True)

#cost_plot = plt.plot(time[start:end], cost[start:end], 'r',time[start:end], xe[start:end], 'b', time[start:end], ye[start:end], 'y', time[start:end], yaw_e[start:end], 'g')
ax2.legend(['reference trajectory', 'SMC'],  prop={'size': 20})
#plt.xlabel(['Time(s)'])
#plt.savefig('adaptive_trajectory.eps', format='eps', dpi=1000)
plt.savefig('smc_trajectory_real.eps', format='eps', dpi=1000, bbox_inches='tight')

# %%
# 1) RGB tuple:

fig, (ax, ax2) = plt.subplots(1,2,facecolor=(.96, .92, .91),figsize=(30,13))
ax.set_title('(a)', color='k', size = 30)
ax2.set_title('(b)', color='k', size = 30)
# 2) hex string:
#ax.set_facecolor('#eafff5')
# 3) gray level string:
#ax.set_title('Cost function and trajectory tracking error - circular trajectory', color='k', size = 30)
# 4) single letter color string
ax.set_xlabel('Time (s)', color='k', size = 25)
# 5) a named color:
ax.set_ylabel('Trajectory error', color='k', size = 25)
# 6) a named xkcd color:
#lines = ax.plot(time2[start2:end2], (x_ref2-x2)[start2:end2], 'm', time2[start2:end2], (y_ref2-y2)[start2:end2], 'k', time2[start2:end2], (yaw_ref2-yaw2)[start2:end2], 'y' )
#after tunning
#lines_2 = ax.plot(time1[start1:end1], x_ref1[start1-80:end1-80]-x1[start1:end1], 'r', time1[start1:end1], y_ref1[start1-80:end1-80]-y1[start1:end1], 'b', time1[start1:end1], yaw_ref1[start1-0:end1-0]-yaw1[start1:end1], 'g' )
#lines = ax.plot(time3[start2:end2], (x_ref3-x3)[start2:end2], 'm', time2[start2:end2], (y_ref2-y2)[start2:end2], 'g' )
#after tunning
lines_2 = ax.plot(time3[start3:end3], x_ref3[start3:end3]-x3[start3:end3], 'r', time3[start3:end3], y_ref3[start3-80:end3-80]-y3[start3:end3], 'b', time3[start3:end3], yaw_ref3[start3-80:end3-80]-yaw3[start3:end3], 'g' )

#plt.setp(lines[0], linewidth=1)
plt.setp(lines_2, linewidth=1)
#lines.set_dashes([2, 2, 10, 2])

ax.yaxis.set_ticks(np.arange(-0.1,0.2,0.05))
#ax.yaxis.set_ticks(np.arange(-1.0,5.0,1.0))
# 8) tab notation:
ax.tick_params(labelcolor='k', labelsize = 25)

# grid on
ax.grid(True)

#cost_plot = plt.plot(time[start:end], cost[start:end], 'r',time[start:end], xe[start:end], 'b', time[start:end], ye[start:end], 'y', time[start:end], yaw_e[start:end], 'g')
ax.legend(['xe(m)', 'ye(m)', 'yaw error (rad/s)'],  prop={'size': 20})
#plt.xlabel(['Time(s)'])


# 4) single letter color string
ax2.set_xlabel('Time (s)', color='k', size = 25)
# 5) a named color:
ax2.set_ylabel('Trajectory error', color='k', size = 25)
# 6) a named xkcd color:
#after tunning
#lines_2 = ax2.plot(time5[start5:end5], x_ref5[start5-0:end5-0]-x5[start5:end5], 'm', time5[start5:end5], y_ref5[start5-0:end5-0]-y5[start5:end5], 'k', time5[start5:end5], yaw_ref5[start5-0:end5-0]-yaw5[start5:end5], 'y' )
#lines = ax2.plot(time4[start4:end4], (x_ref4-x4)[start4:end4], 'r', time4[start4:end4], (y_ref4-y4)[start4:end4], 'b', time4[start4:end4], (yaw_ref4-yaw4)[start4:end4], 'g' )
#lines_2 = ax2.plot(time5[start5:end5], x_ref5[start5-0:end5-0]-x5[start5:end5], 'm', time5[start5:end5], y_ref5[start5-0:end5-0]-y5[start5:end5], 'g')

lines = ax2.plot(time6[start6:end6], (x_ref6-x6)[start6:end6], 'r', time6[start6:end6], (y_ref6-y6)[start6:end6], 'b', time6[start6:end6], (yaw_ref6-yaw6)[start6:end6], 'g' )

#lines = ax2.plot(time4[start4:end4], (x_ref4-x4)[start4:end4], 'm', time4[start4:end4], (y_ref4-y4)[start4:end4], 'k' )
#after tunning
#lines_2 = ax2.plot(time5[start5:end5], x_ref5[start5-0:end5-0]-x5[start5:end5], 'r', time5[start5:end5], y_ref5[start5-0:end5-0]-y5[start5:end5], 'b')

plt.setp(lines, linewidth=1)
#plt.setp(lines_2, linewidth=1)
#lines.set_dashes([2, 2, 10, 2])

#ax2.yaxis.set_ticks(np.arange(-0.1,0.4,0.05))
#ax.yaxis.set_ticks(np.arange(-1.0,5.0,1.0))
# 8) tab notation:
ax2.tick_params(labelcolor='k', labelsize = 25)

# grid on
ax2.grid(True)

#cost_plot = plt.plot(time[start:end], cost[start:end], 'r',time[start:end], xe[start:end], 'b', time[start:end], ye[start:end], 'y', time[start:end], yaw_e[start:end], 'g')
ax2.legend(['xe(m)', 'ye(m)', 'yaw error (rad/s)'],  prop={'size': 20})

#plt.xlabel(['Time(s)'])
#plt.savefig('adaptive_trajectory.eps', format='eps', dpi=1000)
plt.savefig('smc_error_real.eps', format='eps', dpi=1000, bbox_inches='tight')

# %%
# 1) RGB tuple:

fig, (ax, ax2) = plt.subplots(1,2,facecolor=(.96, .92, .91),figsize=(30,13))
ax.set_title('(a)', color='k', size = 30)
ax2.set_title('(b)', color='k', size = 30)
# 2) hex string:
#ax.set_facecolor('#eafff5')
# 3) gray level string:
#ax.set_title('Cost function and trajectory tracking error - circular trajectory', color='k', size = 30)
# 4) single letter color string
ax.set_xlabel('Time (s)', color='k', size = 25)
# 5) a named color:
ax.set_ylabel('Velocities', color='k', size = 25)
# 6) a named xkcd color:
#lines = ax.plot(time2[start2:end2], (x_ref2-x2)[start2:end2], 'm', time2[start2:end2], (y_ref2-y2)[start2:end2], 'k', time2[start2:end2], (yaw_ref2-yaw2)[start2:end2], 'y' )
#after tunning
#lines_2 = ax.plot(time1[start1:end1], x_ref1[start1-80:end1-80]-x1[start1:end1], 'r', time1[start1:end1], y_ref1[start1-80:end1-80]-y1[start1:end1], 'b', time1[start1:end1], yaw_ref1[start1-0:end1-0]-yaw1[start1:end1], 'g' )
#lines = ax.plot(time3[start2:end2], (x_ref3-x3)[start2:end2], 'm', time2[start2:end2], (y_ref2-y2)[start2:end2], 'g' )
#after tunning
lines_2 = ax.plot(time3[start3:end3], vx_local3[start3:end3], 'r', time3[start3:end3], vx_ref3[start3:end3], 'g',time3[start3:end3], omega3[start3:end3], 'b', time3[start3:end3], omega_ref3[start3:end3], 'm'  )

#plt.setp(lines[0], linewidth=1)
plt.setp(lines_2, linewidth=4)
#lines.set_dashes([2, 2, 10, 2])

#ax.yaxis.set_ticks(np.arange(-0.1,0.2,0.05))
#ax.yaxis.set_ticks(np.arange(-1.0,5.0,1.0))
# 8) tab notation:
ax.tick_params(labelcolor='k', labelsize = 25)

# grid on
ax.grid(True)

#cost_plot = plt.plot(time[start:end], cost[start:end], 'r',time[start:end], xe[start:end], 'b', time[start:end], ye[start:end], 'y', time[start:end], yaw_e[start:end], 'g')
ax.legend(['vx(m/s)', 'vx_ref(m/s)', 'omega(rad/s)', 'omega_ref(rad/s)'],  prop={'size': 20})
#plt.xlabel(['Time(s)'])


# 4) single letter color string
ax2.set_xlabel('Time (s)', color='k', size = 25)
# 5) a named color:
ax2.set_ylabel('Trajectory error', color='k', size = 25)
# 6) a named xkcd color:
#after tunning
#lines_2 = ax2.plot(time5[start5:end5], x_ref5[start5-0:end5-0]-x5[start5:end5], 'm', time5[start5:end5], y_ref5[start5-0:end5-0]-y5[start5:end5], 'k', time5[start5:end5], yaw_ref5[start5-0:end5-0]-yaw5[start5:end5], 'y' )
#lines = ax2.plot(time4[start4:end4], (x_ref4-x4)[start4:end4], 'r', time4[start4:end4], (y_ref4-y4)[start4:end4], 'b', time4[start4:end4], (yaw_ref4-yaw4)[start4:end4], 'g' )
#lines_2 = ax2.plot(time5[start5:end5], x_ref5[start5-0:end5-0]-x5[start5:end5], 'm', time5[start5:end5], y_ref5[start5-0:end5-0]-y5[start5:end5], 'g')
lines_2 = ax2.plot(time6[start6:end6], vx_local6[start6:end6], 'r', time6[start6:end6], vx_ref6[start6:end6], 'g',time6[start6:end6], omega6[start6:end6], 'b', time6[start6:end6], omega_ref6[start6:end6], 'm'  )

#lines = ax2.plot(time4[start4:end4], (x_ref4-x4)[start4:end4], 'm', time4[start4:end4], (y_ref4-y4)[start4:end4], 'k' )
#after tunning
#lines_2 = ax2.plot(time5[start5:end5], x_ref5[start5-0:end5-0]-x5[start5:end5], 'r', time5[start5:end5], y_ref5[start5-0:end5-0]-y5[start5:end5], 'b')

plt.setp(lines, linewidth=1)
#plt.setp(lines_2, linewidth=1)
#lines.set_dashes([2, 2, 10, 2])

#ax2.yaxis.set_ticks(np.arange(-0.1,0.4,0.05))
#ax.yaxis.set_ticks(np.arange(-1.0,5.0,1.0))
# 8) tab notation:
ax2.tick_params(labelcolor='k', labelsize = 25)

# grid on
ax2.grid(True)

#cost_plot = plt.plot(time[start:end], cost[start:end], 'r',time[start:end], xe[start:end], 'b', time[start:end], ye[start:end], 'y', time[start:end], yaw_e[start:end], 'g')
ax2.legend(['xe(m)', 'ye(m)'],  prop={'size': 20})

#plt.xlabel(['Time(s)'])
#plt.savefig('adaptive_trajectory.eps', format='eps', dpi=1000)
